# %%
import pandas as pd
import numpy as np

# %%
raw_dir = 'raw/'
df_business = pd.read_csv(raw_dir + 'business.csv')
df_checkin = pd.read_csv(raw_dir + 'checkin.csv')
df_photos = pd.read_csv(raw_dir + 'photos.csv')
df_review = pd.read_csv(raw_dir + 'review.csv')
df_tip = pd.read_csv(raw_dir + 'tip.csv')
df_user = pd.read_csv(raw_dir + 'user.csv')

# %%
print(df_business.shape)
for col in df_business.columns:
    print(col)
df_business.head()
# Out:
# (156639, 101)
# attributes.Ambience.divey
# attributes.RestaurantsDelivery
# attributes.DogsAllowed
# postal_code
# hours.Thursday
# attributes.HairSpecializesIn.coloring
# attributes.BestNights.sunday
# attributes.BYOB
# attributes.AgesAllowed
# attributes.Music.video
# hours.Friday
# latitude
# attributes.Alcohol
# attributes.Ambience.classy
# attributes.RestaurantsTableService
# business_id
# attributes.Ambience.touristy
# attributes.RestaurantsCounterService
# attributes.Corkage
# attributes.RestaurantsGoodForGroups
# categories
# name
# attributes.BusinessAcceptsBitcoin
# attributes.HappyHour
# attributes.WheelchairAccessible
# attributes.Ambience.hipster
# attributes.BusinessAcceptsCreditCards
# is_open
# attributes.DietaryRestrictions.vegetarian
# attributes.Music.live
# attributes.Music.background_music
# neighborhood
# attributes.BusinessParking.lot
# attributes.Music.karaoke
# review_count
# attributes.GoodForMeal.breakfast
# attributes.NoiseLevel
# ...

# %%
print(df_checkin.shape)
for col in df_checkin.columns:
    print(col)
df_checkin.head()
# Out:
# (135148, 169)
# time.Wednesday.14:00
# time.Thursday.0:00
# time.Sunday.14:00
# time.Friday.9:00
# time.Sunday.12:00
# time.Wednesday.8:00
# time.Wednesday.2:00
# time.Wednesday.11:00
# time.Monday.19:00
# time.Tuesday.14:00
# time.Wednesday.20:00
# time.Saturday.7:00
# time.Thursday.15:00
# time.Sunday.23:00
# time.Sunday.6:00
# time.Sunday.9:00
# time.Sunday.11:00
# time.Wednesday.10:00
# time.Sunday.4:00
# time.Saturday.5:00
# time.Wednesday.18:00
# business_id
# time.Tuesday.6:00
# time.Tuesday.10:00
# time.Monday.16:00
# time.Saturday.8:00
# time.Thursday.2:00
# time.Friday.1:00
# time.Friday.11:00
# time.Monday.17:00
# time.Saturday.15:00
# time.Monday.6:00
# time.Monday.9:00
# time.Tuesday.20:00
# time.Saturday.9:00
# time.Friday.15:00
# time.Saturday.11:00
# time.Saturday.1:00
# time.Saturday.14:00
# time.Friday.10:00
# time.Sunday.10:00
# time.Thursday.16:00
# time.Thursday.10:00
# time.Friday.18:00
# time.Sunday.22:00
# time.Sunday.3:00
# time.Friday.22:00
# ...

# %%
print(df_photos.shape)
for col in df_photos.columns:
    print(col)
df_photos.head()
# Out:
# (196278, 4)
# photo_id
# business_id
# label
# caption
#                  photo_id             business_id    label  \
# 0  VZXDC7VBdIXXjE3omVqeMg  JzB7NITHQ7gVHGVZ1ntgIQ     food
# 1  c6Em6dDZ4aVKDI8Lc2BQog  JzB7NITHQ7gVHGVZ1ntgIQ  outside
# 2  VAoFn_z9QF0qVmT5vTdwWA  JzB7NITHQ7gVHGVZ1ntgIQ     food
# 3  ToCK6BSwnST8nIzSuskW3g  JzB7NITHQ7gVHGVZ1ntgIQ     food
# 4  XFsXCbK5q3ks0n7B8grI8A  JzB7NITHQ7gVHGVZ1ntgIQ     food
#
#                                  caption
# 0  Black Angus Steak Sandwich... Huge!!!
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN

# %%
print(df_review.shape)
for col in df_review.columns:
    print(col)
df_review.head()
# Out:
# (4736897, 9)
# funny
# user_id
# review_id
# text
# business_id
# stars
# date
# useful
# cool
#    funny                 user_id               review_id  \
# 0      0  cjpdDjZyprfyDG3RlkVG3w  VfBHSwC5Vz_pbFluy07i9Q
# 1      0  bjTcT8Ty4cJZhEOEo01FGA  3zRpneRKDsOPq92tq7ybAA
# 2      0  AXgRULmWcME7J6Ix3I--ww  ne5WhI1jUFOcRn-b-gAzHA
# 3      0  oU2SSOmsp_A8JYI7Z2JJ5w  llmdwOgDReucVoWEry61Lw
# 4      0  0xtbPEna2Kei11vsU-U2Mw  DuffS87NaSMDmIfluvT83g
#
#                                                 text             business_id  \
# 0  My girlfriend and I stayed here for 3 nights a...  uYHaNptLzDLoV_JZ_MuzUA
# 1  If you need an inexpensive place to stay for a...  uYHaNptLzDLoV_JZ_MuzUA
# 2  Mittlerweile gibt es in Edinburgh zwei Ableger...  uYHaNptLzDLoV_JZ_MuzUA
# 3  Location is everything and this hotel has it! ...  uYHaNptLzDLoV_JZ_MuzUA
# 4  gute lage im stadtzentrum. shoppingmeile und s...  uYHaNptLzDLoV_JZ_MuzUA
#
#    stars        date  useful  cool
# ...

# %%
print(df_tip.shape)
for col in df_tip.columns:
    print(col)
df_tip.head()
# Out:
# (1028802, 5)
# user_id
# text
# business_id
# likes
# date
#                   user_id                                               text  \
# 0  zcTZk7OG8ovAmh_fenH21g              Get here early enough to have dinner.
# 1  ZcLKXikTHYOnYt5VYRO5sg  Great breakfast large portions and friendly wa...
# 2  oaYhjqBbh18ZhU0bpyzSuw  Nice place. Great staff.  A fixture in the tow...
# 3  ulQ8Nyj7jCUR8M83SUMoRQ                     Happy hour 5-7 Monday - Friday
# 4  ulQ8Nyj7jCUR8M83SUMoRQ  Parking is a premium, keep circling, you will ...
#
#               business_id  likes        date
# 0  tJRDll5yqpZwehenzE2cSg      0  2012-07-15
# 1  jH19V2I9fIslnNhDzPmdkA      0  2015-08-12
# 2  dAa0hB2yrnHzVmsCkN4YvQ      0  2014-06-20
# 3  dAa0hB2yrnHzVmsCkN4YvQ      0  2016-10-12
# 4  ESzO3Av0b1_TzKOiqzbQYQ      0  2017-01-28

# %%
print(df_user.shape)
for col in df_user.columns:
    print(col)
df_user.head()
# Out:
# (1183362, 22)
# yelping_since
# useful
# compliment_photos
# compliment_list
# compliment_funny
# compliment_plain
# review_count
# elite
# fans
# compliment_note
# funny
# compliment_writer
# compliment_cute
# average_stars
# user_id
# compliment_more
# friends
# compliment_hot
# cool
# name
# compliment_profile
# compliment_cool
#   yelping_since  useful  compliment_photos  compliment_list  compliment_funny  \
# 0    2010-07-13   17019               7829               78              5174
# 1    2006-01-18   83681                162              101              1556
# 2    2014-10-31      45                  8                0                15
# 3    2013-04-01      15                  1                0                 9
# 4    2012-08-16    9152                169                0               276
#
#    compliment_plain  review_count  \
# 0              7397           272
# 1              2134          2559
# 2                20           277
# ...
